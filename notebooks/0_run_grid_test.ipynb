# %%
# %load_ext autoreload

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s') # NOTSET, DEBUG, INFO, WARN, ERROR, CRITICAL

from mcfs.compute_grid_fake_spectra import run_gridded_skewers

# %%
lines = [
    ("H", 1, 1215),
    ("Si", 3, 1206),
    ("Si", 2, 1190),
    ("Si", 2, 1193),
]

gs, info = run_gridded_skewers(
    base="/home/STORAGE/TNG50-4",
    num=33,
    nspec=2,
    axis=2,
    nbins=1024,
    lines=lines,
    out_dir="/home/STORAGE/SKEWERS/TNG50-4/snapdir_033",
    savefile="grid_TNG50-4_snap033_nspec2_axis2_nbins1024_test.hdf5",
    overwrite=True,
    force_recompute_tau=True,
    kernel="tophat",
    compute_density=True,
    compute_temperature=True,
    compute_velocity_los=True,
    quiet=False,
)
# Out:
# [07:41:52] [INFO] Starting gridded skewer run
# [07:41:52] [INFO] base=/home/STORAGE/TNG50-4
# [07:41:52] [INFO] snapshot=033 | nspec=2 | axis=2
# [07:41:52] [INFO] nbins=1024 | res_kms=None | kernel=tophat | MPI ranks=1
# [07:41:52] [INFO] Output directory ready: /home/STORAGE/SKEWERS/TNG50-4/snapdir_033
# [07:41:52] [INFO] Will build/load from snapshot and write output: /home/STORAGE/SKEWERS/TNG50-4/snapdir_033/grid_TNG50-4_snap033_nspec2_axis2_nbins1024_test.hdf5
# Reloading from snapshot (will save to:  /home/STORAGE/SKEWERS/TNG50-4/snapdir_033/grid_TNG50-4_snap033_nspec2_axis2_nbins1024_test.hdf5  )
# [07:41:52] [INFO] Spectra object ready: nbins=1024 | dvbin=3.425 km/s | vmax=3507.013 km/s
# [07:41:52] [INFO] Computing tau for H1_1215
# 4  sightlines. resolution:  3.4248177531710557  z= 2.0020281392528516
# rank = 0 | Interpolation 9.1 percent done
# rank = 0 | Interpolation 18.2 percent done
# rank = 0 | Interpolation 27.3 percent done
# rank = 0 | Interpolation 36.4 percent done
# rank = 0 | Interpolation 45.5 percent done
# rank = 0 | Interpolation 54.5 percent done
# rank = 0 | Interpolation 63.6 percent done
# rank = 0 | Interpolation 72.7 percent done
# rank = 0 | Interpolation 81.8 percent done
# rank = 0 | Interpolation 90.9 percent done
# [07:41:53] [INFO] Computed H1_1215 with shape (4, 1024)
# [07:41:53] [INFO] Computing tau for Si3_1206
# rank = 0 | Interpolation 9.1 percent done
# rank = 0 | Interpolation 18.2 percent done
# rank = 0 | Interpolation 27.3 percent done
# rank = 0 | Interpolation 36.4 percent done
# rank = 0 | Interpolation 45.5 percent done
# rank = 0 | Interpolation 54.5 percent done
# rank = 0 | Interpolation 63.6 percent done
# rank = 0 | Interpolation 72.7 percent done
# rank = 0 | Interpolation 81.8 percent done
# rank = 0 | Interpolation 90.9 percent done
# [07:41:53] [INFO] Computed Si3_1206 with shape (4, 1024)
# [07:41:53] [INFO] Computing tau for Si2_1190
# rank = 0 | Interpolation 9.1 percent done
# rank = 0 | Interpolation 18.2 percent done
# rank = 0 | Interpolation 27.3 percent done
# rank = 0 | Interpolation 36.4 percent done
# rank = 0 | Interpolation 45.5 percent done
# rank = 0 | Interpolation 54.5 percent done
# rank = 0 | Interpolation 63.6 percent done
# rank = 0 | Interpolation 72.7 percent done
# rank = 0 | Interpolation 81.8 percent done
# rank = 0 | Interpolation 90.9 percent done
# [07:41:54] [INFO] Computed Si2_1190 with shape (4, 1024)
# [07:41:54] [INFO] Computing tau for Si2_1193
# rank = 0 | Interpolation 9.1 percent done
# rank = 0 | Interpolation 18.2 percent done
# rank = 0 | Interpolation 27.3 percent done
# rank = 0 | Interpolation 36.4 percent done
# rank = 0 | Interpolation 45.5 percent done
# rank = 0 | Interpolation 54.5 percent done
# rank = 0 | Interpolation 63.6 percent done
# rank = 0 | Interpolation 72.7 percent done
# rank = 0 | Interpolation 81.8 percent done
# rank = 0 | Interpolation 90.9 percent done
# [07:41:55] [INFO] Computed Si2_1193 with shape (4, 1024)
# [07:41:55] [INFO] Computing density for H1
# rank = 0 | Interpolation 9.1 percent done
# rank = 0 | Interpolation 18.2 percent done
# rank = 0 | Interpolation 27.3 percent done
# rank = 0 | Interpolation 36.4 percent done
# rank = 0 | Interpolation 45.5 percent done
# rank = 0 | Interpolation 54.5 percent done
# rank = 0 | Interpolation 63.6 percent done
# rank = 0 | Interpolation 72.7 percent done
# rank = 0 | Interpolation 81.8 percent done
# rank = 0 | Interpolation 90.9 percent done
# [07:41:55] [INFO] Density H1 shape (4, 1024)
# [07:41:55] [INFO] Computing temperature for H1
# [07:41:56] [INFO] Temperature H1 shape (4, 1024)
# [07:41:56] [INFO] Computing LOS velocity for H1
# [07:41:57] [INFO] LOS velocity H1 shape (4, 1024)
# [07:41:57] [INFO] Computing density for Si2
# rank = 0 | Interpolation 9.1 percent done
# rank = 0 | Interpolation 18.2 percent done
# rank = 0 | Interpolation 27.3 percent done
# rank = 0 | Interpolation 36.4 percent done
# rank = 0 | Interpolation 45.5 percent done
# rank = 0 | Interpolation 54.5 percent done
# rank = 0 | Interpolation 63.6 percent done
# rank = 0 | Interpolation 72.7 percent done
# rank = 0 | Interpolation 81.8 percent done
# rank = 0 | Interpolation 90.9 percent done
# [07:41:58] [INFO] Density Si2 shape (4, 1024)
# [07:41:58] [INFO] Computing temperature for Si2
# [07:41:58] [INFO] Temperature Si2 shape (4, 1024)
# [07:41:58] [INFO] Computing LOS velocity for Si2
# [07:41:59] [INFO] LOS velocity Si2 shape (4, 1024)
# [07:41:59] [INFO] Computing density for Si3
# rank = 0 | Interpolation 9.1 percent done
# rank = 0 | Interpolation 18.2 percent done
# rank = 0 | Interpolation 27.3 percent done
# rank = 0 | Interpolation 36.4 percent done
# rank = 0 | Interpolation 45.5 percent done
# rank = 0 | Interpolation 54.5 percent done
# rank = 0 | Interpolation 63.6 percent done
# rank = 0 | Interpolation 72.7 percent done
# rank = 0 | Interpolation 81.8 percent done
# rank = 0 | Interpolation 90.9 percent done
# [07:42:00] [INFO] Density Si3 shape (4, 1024)
# [07:42:00] [INFO] Computing temperature for Si3
# [07:42:01] [INFO] Temperature Si3 shape (4, 1024)
# [07:42:01] [INFO] Computing LOS velocity for Si3
# [07:42:01] [INFO] LOS velocity Si3 shape (4, 1024)
# [07:42:01] [INFO] Saving HDF5 output
# [07:42:01] [INFO] Manifest written to: /home/STORAGE/SKEWERS/TNG50-4/snapdir_033/grid_TNG50-4_snap033_nspec2_axis2_nbins1024_test.hdf5.json
# [07:42:01] [INFO] Run completed successfully
